// %% [markdown]
// # C++ 실습 확인용 노트북
// 셀을 실행해 커널이 동작하는지 확인하세요. 커널 선택 창이 나오면 **C++20**을 고르세요.

// %%
#include <iostream>
std::cout << "안녕하세요, C++ 실행기입니다." << std::endl;

// %%
#include <vector>
#include <numeric>
std::vector<int> v{1,2,3,4,5};
int 합 = std::accumulate(v.begin(), v.end(), 0);
std::cout << "1~5의 합: " << 합 << std::endl;
